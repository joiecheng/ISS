# %%
# !pip install requests
# !pip install matplotlib
# Out:
# Requirement already satisfied: requests in /Users/joiecheng/anaconda3/lib/python3.10/site-packages (2.28.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/joiecheng/anaconda3/lib/python3.10/site-packages (from requests) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/joiecheng/anaconda3/lib/python3.10/site-packages (from requests) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/joiecheng/anaconda3/lib/python3.10/site-packages (from requests) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/joiecheng/anaconda3/lib/python3.10/site-packages (from requests) (2022.12.7)
# Requirement already satisfied: matplotlib in /Users/joiecheng/anaconda3/lib/python3.10/site-packages (3.7.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/joiecheng/anaconda3/lib/python3.10/site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: packaging>=20.0 in /Users/joiecheng/anaconda3/lib/python3.10/site-packages (from matplotlib) (22.0)
# Requirement already satisfied: numpy>=1.20 in /Users/joiecheng/anaconda3/lib/python3.10/site-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: pillow>=6.2.0 in /Users/joiecheng/anaconda3/lib/python3.10/site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/joiecheng/anaconda3/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/joiecheng/anaconda3/lib/python3.10/site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/joiecheng/anaconda3/lib/python3.10/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /Users/joiecheng/anaconda3/lib/python3.10/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/joiecheng/anaconda3/lib/python3.10/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: six>=1.5 in /Users/joiecheng/anaconda3/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import requests
import matplotlib.pyplot as plt
import time

# %%
latitudes=[]
longitudes=[]
timestamps=[]

for x in range(100):
    response=requests.get("http://api.open-notify.org/iss-now.json")
    data=response.json()
    
    timestamp=int(data["timestamp"])
    latitude=float(data["iss_position"]["latitude"])
    longitude=float(data["iss_position"]["longitude"])
    
    latitudes.append(latitude)
    longitudes.append(longitude)
    timestamps.append(timestamp)
    
    time.sleep(10)

    
plt.scatter(longitudes, latitudes)
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Path of the International Space Station')
plt.show()
